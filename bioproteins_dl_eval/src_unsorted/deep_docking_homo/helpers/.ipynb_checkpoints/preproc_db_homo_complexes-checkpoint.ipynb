# %%
from IPython import get_ipython
ipython = get_ipython()
ipython.magic('load_ext autoreload')
ipython.magic('autoreload 2')


import logging
logging.basicConfig(level=logging.INFO)
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


import pickle as pkl
import sys
sys.path.append('/home/annaha/projects/homodimers/bioproteins_dl_eval/src_unsorted/bio_utils')
sys.path.append('/home/annaha/projects/homodimers/bioproteins_dl_eval/src_unsorted/deep_docking_homo')
from task_utils import parallel_tasks_run_def
from deephd_core import read_homo_pdb_coords
import scipy.spatial.distance as sdst
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# path_idx = '/home/ar/data/bioinformatics/deepdocking_experiments/homodimers/raw/idx.txt'
path_idx = '/mnt/data2t2/data/annaha/paperdataset/pdb_raw/idx-paper.txt'
wdir = os.path.dirname(path_idx)
data_idx = pd.read_csv(path_idx)
paths_pdb = [os.path.join(wdir, f'{x.upper()}.pdb1') for x in data_idx['path']]
logging.info(f'\n#PDBs = {len(paths_pdb)}')
# Out:
# INFO:root:
# #PDBs = 50

# %%
def prepare_and_dump_matrices(path_pdb, num_models=2):
    path_out = os.path.splitext(path_pdb)[0] + '_dumpl.pkl'
    if os.path.isfile(path_out):
        logging.warning('\t*** output exist, skip... [{}]'.format(path_out))
        return True
    try:
        pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
    except Exception as err:
        logging.exception('\t!!!! cant process PDB, skip... err=[{}], [{}]'
                          .format(err, path_pdb))
        return False
    if (num_models is None) or (pdb_info['num'] == num_models):
        with open(path_out, 'wb') as f:
            pkl.dump(pdb_info, f)
        return True
    else:
        logging.warning('\t!!! skip PDB, #models != {}, #models={}, pfb={}'
                        .format(num_models, pdb_info['num'], path_pdb))
        return False

# %%
task_data = [[x] for x in paths_pdb]
ret = parallel_tasks_run_def(prepare_and_dump_matrices, task_data, num_workers=16)
# Out:
# INFO:root::: start (unnamed-task) #data/#threads = 31723/16, use-process(True)
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/10GS_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/14GS_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/11BA_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/117E_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/11AS_raw_dumpl.pkl]
# INFO:root:	[0/31723] (l1) (unnamed-task)
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/11BG_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/16GS_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/13GS_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/13GS_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/13GS_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/18GS_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/17GS_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/17GS_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/17GS_raw.pdb'
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/137L_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/137L_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/137L_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A05_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A0F_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A0M_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/19HC_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A19_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/19GS_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A18_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A09_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1A09_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A09_raw.pdb'
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A0G_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1A0G_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A0G_raw.pdb'
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A15_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1A15_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A15_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/12GS_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/11GS_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/121P_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/12AS_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A25_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A1X_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A27_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A2D_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A2W_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A3C_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A43_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A3Y_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1A3Y_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A3Y_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A45_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A4B_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A3A_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1A3A_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A3A_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A4C_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A4H_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A4R_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A4U_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A4X_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A59_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A4I_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1A4I_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A4I_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A4O_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A5T_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A52_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1A52_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A52_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A5V_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A5X_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A5W_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A6I_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A64_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A5H_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1A5H_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1A5H_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A6P_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A71_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A78_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A7G_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A7U_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A72_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A7W_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A7X_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A82_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A7T_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A8J_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A8G_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A8I_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A8L_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A8Y_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A8U_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A94_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A99_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A8K_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A8O_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A9M_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A9Y_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1A9Z_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AAP_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AA7_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AA7_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AA7_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AAM_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AAR_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AAQ_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AAT_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AB4_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AAW_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AB0_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ABQ_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AC1_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AB8_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AB8_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AB8_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AC6_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ACD_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ACJ_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ACL_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ACV_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AD3_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ADC_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ADE_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ADG_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AD4_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AD4_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AD4_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ADF_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ADB_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AD1_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AD1_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AD1_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ADI_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ADJ_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ADW_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1ADU_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1ADU_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1ADU_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ADY_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AE1_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AE1_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AE1_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AF2_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AE3_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AF5_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ADL_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AE2_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AFR_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AFS_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AGN_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AFW_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AFW_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AFW_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AG9_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AH6_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AGP_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AHE_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AG1_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AGS_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AHF_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AHP_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AH8_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AH8_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AH8_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AHY_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AHX_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AI2_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AI3_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AIB_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AIA_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AI9_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AIC_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AID_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AIQ_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AIL_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AIU_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AIZ_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AIH_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AIH_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AIH_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AJ5_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AJ8_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AJ8_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AJ8_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AJB_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AJD_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AJR_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AJM_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AJC_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AJC_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AJC_raw.pdb'
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AJA_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AJA_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AJA_raw.pdb'
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AJS_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AJS_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AJS_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AJV_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AJX_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AKA_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AKB_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ALI_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AKC_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ALH_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ALK_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ALU_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ALN_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AL6_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ALJ_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ALW_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ALV_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AM1_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AM2_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AMA_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AMP_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AMH_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AMW_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AMS_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AMR_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AMK_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AN9_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ANC_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AN8_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AMZ_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ANB_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ANE_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AND_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AMQ_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AN5_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ANG_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AN0_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AN0_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AN0_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ANJ_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ANI_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1ANT_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1ANT_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1ANT_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1ANU_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AOB_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AOC_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AOH_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AOH_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AOH_raw.pdb'
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AOF_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AOF_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AOF_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1AOJ_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AOG_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1AOG_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1AOG_raw.pdb'
# ...
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1ICW_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IDE_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IDN_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IDR_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1IDR_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IDR_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IDD_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IE0_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IDF_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IDM_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IE3_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IEC_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1IEC_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IEC_raw.pdb'
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IEF_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1IEF_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IEF_raw.pdb'
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IED_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1IED_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IED_raw.pdb'
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IDT_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1IDT_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IDT_raw.pdb'
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IEG_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1IEG_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IEG_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IFT_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IFU_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IFS_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IF2_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IFX_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IG0_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1IG0_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IG0_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IFV_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IGZ_raw_dumpl.pkl]
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IHO_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IGU_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1IGU_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IGU_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IHB_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IGQ_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1IGQ_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IGQ_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IHK_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IH8_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1IH8_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IH8_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1IGB_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IHR_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1IHR_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IHR_raw.pdb'
# WARNING:root:	*** output exist, skip... [/home/annaha/bioinf/data/pdb_raw/1II5_raw_dumpl.pkl]
# ERROR:root:	!!!! cant process PDB, skip... err=[[Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IG3_raw.pdb'], [/home/annaha/bioinf/data/pdb_raw/1IG3_raw.pdb]
# Traceback (most recent call last):
#   File "<ipython-input-3-d952310d9962>", line 7, in prepare_and_dump_matrices
#     pdb_info = read_homo_pdb_coords(path_pdb, calc_dst=False)
#   File "/home/annaha/bioinf/bioproteins_dl/src_unsorted/deep_docking_homo/deephd_core.py", line 25, in read_homo_pdb_coords
#     models_ = list(pdb_parser.get_structure(os.path.basename(path_pdb), path_pdb).get_models())
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/PDB/PDBParser.py", line 85, in get_structure
#     with as_handle(file, mode='rU') as handle:
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/home/annaha/anaconda3/envs/py376/lib/python3.7/site-packages/Bio/File.py", line 118, in as_handle
#     with open(handleish, mode, **kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annaha/bioinf/data/pdb_raw/1IG3_raw.pdb'

# %%
paths_pkl = sorted(glob.glob('/home/ar/data/bioinformatics/deepdocking_experiments/homodimers/raw/homo/*_raw_dumpl.pkl'))
print(f'#pkl = {len(paths_pkl)}')
# Out:
# #pkl = 1009

# %%
data_11 = []
data_12 = []
data_num = []
for x in paths_pkl:
    d = pkl.load(open(x, 'rb'))
    x1, x2 = d['coords']
    data_11.append(sdst.cdist(x1, x1).mean())
    data_12.append(sdst.cdist(x1, x2).mean())
    data_num.append(len(d['res'][0]))
data_11 = np.array(data_11)
data_12 = np.array(data_12)
data_num = np.array(data_num)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(data_num, data_11 / np.power(data_num, 1/3), 'o')
plt.grid()
plt.subplot(1, 2, 2)
plt.plot(data_num, data_12 / np.power(data_num, 1/3), 'o')
plt.grid()

# %%
q11 = sdst.cdist(x1, x1)
q12 = sdst.cdist(x1, x2)

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.imshow(q11 < 16)
plt.subplot(1, 2, 2)
plt.imshow(q12 < 16)
