# %%
import os
import glob
files = (glob.glob("/mnt/data2t2/data/annaha/pdb_raw/*6tr_dumpl.pkl"))
vdir = set()
#vfile = set()
for f in files:
    #print(f)
    vdir.add(f[-21:-13])
    #print(f.lower())
    #os.rename(f, f.lower())
#path = '/home/annaha/bioinf/data/pdb_raw/'
#print(vdir)
f = open('/mnt/data2t2/data/annaha/idx-okl_cb_val0_sh_fixtr6.txt')
wf = open('/mnt/data2t2/data/annaha/idx-okl_cb_val0_sh_fixtr6n.txt', 'w')
for s in f:
    temps = s[-22:-14]
    if(temps in vdir):
        wf.write(s)
    print(temps)
wf.flush()
wf.close()
# Out:
# 1jzk_raw
# 3g1c_raw
# 4a47_raw
# 3aux_raw
# 1wz7_raw
# 5vp5_raw
# 4qgi_raw
# 1j0a_raw
# 4fer_raw
# 3tg2_raw
# 1r0e_raw
# 3w1x_raw
# 5u4h_raw
# 3kuw_raw
# 3uf3_raw
# 3bft_raw
# 5w8s_raw
# 1yai_raw
# 3klm_raw
# 3mbd_raw
# 1ivl_raw
# 4j0n_raw
# 4p2p_raw
# 2gxg_raw
# 3ipi_raw
# 1vpi_raw
# 6dlx_raw
# 2vc1_raw
# 2y43_raw
# 4k6a_raw
# 3e7g_raw
# 4ghm_raw
# 4ovy_raw
# 2old_raw
# 1rz0_raw
# 2qld_raw
# 3p0f_raw
# 2xlw_raw
# 1zos_raw
# 1xp6_raw
# 4es1_raw
# 4gqv_raw
# 4pun_raw
# 2ped_raw
# 6fri_raw
# 4ng6_raw
# 1pbb_raw
# 3i6o_raw
# 4opf_raw
# 4y0p_raw
# 4nq1_raw
# 4eib_raw
# 4b1r_raw
# 2f8c_raw
# 5frt_raw
# 1sei_raw
# 1uak_raw
# 2y4r_raw
# 3r88_raw
# 6g9c_raw
# 1s60_raw
# 5jve_raw
# 1lgp_raw
# 3tm1_raw
# 3qy0_raw
# 1tfg_raw
# 3av7_raw
# 5vog_raw
# 3i0j_raw
# 3g26_raw
# 1jfg_raw
# 4ics_raw
# 3g4q_raw
# 4qyt_raw
# 5z5y_raw
# 2qii_raw
# 6g7a_raw
# 6dyv_raw
# 4xbl_raw
# 3vmj_raw
# 4q8u_raw
# 5ezg_raw
# 2zz2_raw
# 5vo3_raw
# 2w7v_raw
# 1jax_raw
# 3t7m_raw
# 4cf9_raw
# 5qj9_raw
# 3vtk_raw
# ...
